# %%
import cv2 as cv
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import math
import random
# %matplotlib inline

# %%
def show_img(img):
    fig = plt.figure(figsize=(18, 16), dpi = 80, facecolor='w', edgecolor='k')
    plt.imshow(img)

# %%
def blur_img(img, blur_level):
    h, w = img.shape
    rw, rh = math.floor(w/blur_level), math.floor(h/blur_level)
    img_resized = cv.resize(img, (rw, rh))
    img_blured = cv.resize(img_resized, (w, h))
    return img_blured

# %%
def sub_img(img, wsub, hsub):
    blur_pieces = []
    h, w = img.shape
    wsubsize, hsubsize = math.floor(w/wsub), math.floor(h/hsub)
    for i in range(hsub-1):
        for j in range(wsub-1):
            blur_pieces.append(img[hsubsize*i:hsubsize*(i+1), wsubsize*j:wsubsize*(j+1)])
    return blur_pieces

# %%
def to_binary(img):
    thresh, im = cv.threshold(img, 170,255, cv.THRESH_BINARY );
    return im

# %% [markdown]
# ### Load Data

# %%
import glob

training_path = './data/Book/'
training_data = []
img_set, blur_set = [], []
for filename in glob.glob(training_path+'/*.jpg'):
    im = cv.imread(filename, 0)
    w, h = im.shape
    im = cv.resize(im, (math.floor(h/3), math.floor(w/3)))
    im = sub_img(im, 9*6, 12*6)
    img_set += [x / 255 for x in im]
random.shuffle(img_set)

# %%
# %matplotlib inline
pick_random = random.randrange(len(img_set))
# print(img_set[pick_random])
plt.imshow(img_set[pick_random])

# %%
test = blur_img(img_set[pick_random], blur_level=1.5+random.random())
plt.imshow(test)

# %%
print('Number of images:', len(img_set), 'Size:', img_set[0].shape)
# Out:
# Number of images: 150520 Size: (18, 18)

# %% [markdown]
# ### Building Model

# %% [markdown]
# Placeholders

# %%
IMGSIZE = img_set[0].shape[0]
COLOR_CHANNELS = 1
print(IMGSIZE)
data_ph = tf.placeholder('float32',[None, IMGSIZE*IMGSIZE*COLOR_CHANNELS])
output_ph = tf.placeholder('float32',[None, IMGSIZE*IMGSIZE*COLOR_CHANNELS])
learning_rate = tf.placeholder('float', [], name = 'learning_rate_ph')
# Out:
# 18

# %%
def init_weights(shape):
    init_random_dist = tf.truncated_normal(shape, stddev = 1.1)
    return tf.Variable(init_random_dist)

# %%
def init_bias(shape):
    init_bias_vals = tf.constant(0.1, shape=shape)
    return tf.Variable(init_bias_vals)

# %%
def conv2d(x, W):
    #x -> [batch, H, W, Channels]
    #W -> [filter H, filter W, Channels IN, Channels Out]
    return tf.nn.conv2d(x, W, strides = [1,1,1,1], padding='SAME')

# %%
def deconvolutional_layer(input_x, shape):
    W = init_weights(shape)
    b = init_bias([shape[3]])
    return tf.nn.relu(tf.nn.conv2d_transpose(input_x, W, shape, strides = [1,1,1,1], padding='SAME')+b)

# %%
def  convolutional_layer(input_x, shape):
    W = init_weights(shape)
    b = init_bias([shape[3]])
    return tf.nn.relu(conv2d(input_x, W)+b)

# %% [markdown]
# Layers

# %%
hl1 = tf.reshape(data_ph, [-1, IMGSIZE, IMGSIZE, 1])
hl2 = convolutional_layer(hl1, [3, 3, 1, 12])
# hl3 = convolutional_layer(hl2, [3, 3, 12, 12])
# hl4 = convolutional_layer(hl3, [3, 3, 12, 12])
hl5 = convolutional_layer(hl2, [3, 3, 12, 1])
ol = tf.nn.sigmoid(hl5)
ol_residual = tf.reshape(ol, [-1, IMGSIZE*IMGSIZE*COLOR_CHANNELS])
ol = tf.contrib.layers.fully_connected(ol_residual, IMGSIZE*IMGSIZE*COLOR_CHANNELS, activation_fn=tf.nn.sigmoid)
ol = ol_residual + ol

mean1, var1 = tf.nn.moments(output_ph, axes=[0])
mean2, var2 = tf.nn.moments(ol, axes=[0])
# print(mean.shape)
loss = tf.reduce_mean((ol - output_ph)**2)+(tf.reduce_mean(var2)-tf.reduce_mean(var1))**2
train = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

# %% [markdown]
# Load Batch

# %%
def load_batch(size, blur):
    batch_x, batch_y = [], []
    for _ in range(size):
        rand_val = random.randrange(0, len(img_set))
        if blur:
            batch_x.append(np.array(blur_img(img_set[rand_val], blur_level=1.5+random.random())).ravel())
        else:
            batch_x.append(np.array(img_set[rand_val]).ravel())
        batch_y.append(np.array(img_set[rand_val]).ravel())
    return batch_x, batch_y

# %% [markdown]
# Running session

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
# %matplotlib notebook
import time

start = time.time()
batch_size = 10
steps = 550000
rate = 3e-4

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

with tf.Session() as sess:
    sess.run(init)
    for i in range(steps):
        batch_x, batch_y = load_batch(batch_size, blur=False)
        feed = {data_ph:batch_x, output_ph:batch_y, learning_rate:rate}
        sess.run(train, feed_dict=feed)
        
        if i%100 == 0:
            last_loss = sess.run(loss, feed_dict = feed)
            print(last_loss)
            if last_loss<0.0055:
                rate = 3e-5
#             pred = sess.run(ol, feed_dict={data_ph:[np.array(blur_img(img_set[pick_random], blur_level=3+random.random())).ravel()]})
            pred = sess.run(ol, feed_dict={data_ph:[np.array(img_set[pick_random]).ravel()]})
            ax.clear()
            ax.imshow(np.reshape(pred, [IMGSIZE, IMGSIZE]))
            fig.canvas.draw()

end = time.time()
elapsed = end - start
print(elapsed)
# Out:
# <img src="data:image/png;base64,..." width="431.53847736719854">
# 0.195526
# 0.200062
# 0.196433
# 0.19032
# 0.245665
# 0.12377
# 0.136762
# 0.160106
# 0.153057
# 0.186685
# 0.275766
# 0.201904
# 0.225601
# 0.173791
# 0.147841
# 0.17485
# 0.212652
# 0.15908
# 0.169038
# 0.15229
# 0.187862
# 0.204412
# 0.16824
# 0.235637
# 0.24687
# 0.196962
# 0.299415
# 0.175072
# 0.17648
# 0.187854
# 0.304923
# 0.126741
# 0.220749
# 0.182229
# 0.225614
# 0.156088
# 0.261988
# 0.177306
# 0.209261
# 0.22455
# 0.176748
# 0.295441
# 0.188532
# 0.214141
# 0.258995
# 0.191428
# 0.172162
# 0.150213
# 0.18534
# 0.26906
# 0.169313
# 0.177109
# 0.225547
# 0.273132
# 0.13371
# 0.236635
# 0.205521
# 0.224244
# 0.20858
# 0.239566
# 0.154477
# 0.141197
# 0.214246
# 0.376512
# 0.160359
# 0.217393
# 0.138965
# 0.212536
# 0.241078
# 0.160997
# 0.235529
# 0.160136
# 0.185465
# 0.178633
# 0.105738
# 0.267961
# 0.275058
# 0.255959
# 0.213118
# 0.123368
# 0.211718
# 0.172948
# 0.175661
# 0.113419
# 0.180369
# 0.173164
# 0.200215
# 0.118046
# 0.156083
# 0.169168
# 0.171024
# 0.261892
# 0.24584
# 0.247686
# 0.139639
# 0.180202
# 0.155976
# 0.217914
# 0.0573635
# 0.0614271
# 0.0550863
# 0.0268191
# 0.0435229
# 0.0192164
# 0.00958035
# 0.0259767
# 0.0581589
# 0.0662726
# 0.0273915
# 0.0718441
# 0.0546275
# 0.0333264
# 0.0845896
# 0.0368079
# 0.0370767
# 0.0862107
# 0.0920558
# 0.0326147
# 0.0687376
# 0.0414031
# 0.0342609
# 0.0788349
# 0.0655771
# 0.083195
# 0.0380073
# 0.038183
# 0.0336225
# 0.0146045
# 0.0556685
# 0.0749113
# 0.0421591
# 0.0721595
# 0.154411
# 0.0229387
# 0.061032
# 0.0545564
# 0.0468543
# 0.0845413
# 0.0396962
# 0.0750086
# 0.0392105
# 0.0478089
# 0.0650559
# 0.0465536
# 0.0428352
# 0.0453263
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-8d1dba98c386> in <module>()
#      28 #             pred = sess.run(ol, feed_dict={data_ph:[np.array(blur_img(img_set[pick_random], blur_level=3+random.random())).ravel()]})
#      29             pred = sess.run(ol, feed_dict={data_ph:[np.array(img_set[pick_random]).ravel()]})
# ---> 30             ax.clear()
#      31             ax.imshow(np.reshape(pred, [IMGSIZE, IMGSIZE]))
#      32             fig.canvas.draw()
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in clear(self)
#    1129     def clear(self):
#    1130         """clear the axes"""
# -> 1131         self.cla()
#    1132
#    1133     def get_facecolor(self):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in cla(self)
#     982         self.yaxis.cla()
#     983         for name, spine in six.iteritems(self.spines):
# --> 984             spine.cla()
#     985
#     986         self.ignore_existing_data_limits = True
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/spines.py in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in reset_ticks(self)
#     772         cbook.popall(self.minorTicks)
#     773
# --> 774         self.majorTicks.extend([self._get_tick(major=True)])
#     775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick(self, major)
#    2058         else:
#    2059             tick_kw = self._minor_tick_kw
# -> 2060         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2061
#    2062     def _get_label(self):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick1line(self)
#     555                           markeredgewidth=self._width,
#     556                           zorder=self._zorder)
# --> 557         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     558         self._set_artist_props(l)
#     559         return l
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in get_yaxis_transform(self, which)
#     784         elif which == 'tick1':
#     785             # for cartesian projection, this is bottom spine
# --> 786             return self.spines['left'].get_spine_transform()
#     787         elif which == 'tick2':
#     788             # for cartesian projection, this is top spine
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/spines.py in get_spine_transform(self)
#     404     def get_spine_transform(self):
#     405         """get the spine transform"""
# --> 406         self._ensure_position_is_set()
#     407         what, how = self._spine_transform
#     408
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/spines.py in _ensure_position_is_set(self)
#     150             # default position
#     151             self._position = ('outward', 0.0)  # in points
# --> 152             self.set_position(self._position)
#     153
#     154     def register_axis(self, axis):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/spines.py in set_position(self, position)
#     394
#     395         if self.axis is not None:
# --> 396             self.axis.reset_ticks()
#     397         self.stale = True
#     398
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in reset_ticks(self)
#     772         cbook.popall(self.minorTicks)
#     773
# --> 774         self.majorTicks.extend([self._get_tick(major=True)])
#     775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick(self, major)
#    2058         else:
#    2059             tick_kw = self._minor_tick_kw
# -> 2060         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2061
#    2062     def _get_label(self):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     149
#     150         self.tick1line = self._get_tick1line()
# --> 151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#     153
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick2line(self)
#     568                           markersize=self._size,
#     569                           markeredgewidth=self._width,
# --> 570                           zorder=self._zorder)
#     571         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     572         self._set_artist_props(l)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         self._color = None
#     403         self.set_color(color)
# --> 404         self._marker = MarkerStyle()
#     405         self.set_marker(marker)
#     406
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     184         # _recache() in set_marker.
#     185         self._fillstyle = fillstyle
# --> 186         self.set_marker(marker)
#     187         self.set_fillstyle(fillstyle)
#     188
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/markers.py in set_marker(self, marker)
#     270
#     271         self._marker = marker
# --> 272         self._recache()
#     273
#     274     def get_path(self):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/markers.py in _recache(self)
#     198
#     199     def _recache(self):
# --> 200         self._path = Path(np.empty((0, 2)))
#     201         self._transform = IdentityTransform()
#     202         self._alt_path = None
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     160         self._codes = codes
#     161         self._interpolation_steps = _interpolation_steps
# --> 162         self._update_values()
#     163
#     164         if readonly:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/path.py in _update_values(self)
#     217         )
#     218         self._simplify_threshold = rcParams['path.simplify_threshold']
# --> 219         self._has_nonfinite = not np.isfinite(self._vertices).all()
#     220
#     221     @property
#
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims)
#      39
#      40 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 41     return umr_all(a, axis, dtype, out, keepdims)
#      42
#      43 def _count_reduce_items(arr, axis):
#
# KeyboardInterrupt:
# <img src="data:image/png;base64,..." width="431.53847736719854">

# %%
# %matplotlib inline
fig = plt.figure()
ax1 = fig.add_subplot(1,3,1)
ax1.imshow(img_set[pick_random])
ax2 = fig.add_subplot(1,3,2)
ax2.imshow(np.reshape(pred, [IMGSIZE,IMGSIZE]))
ax3 = fig.add_subplot(1,3,3)
ax3.imshow((img_set[pick_random]-np.reshape(pred, [IMGSIZE,IMGSIZE]))**2)

# %%
time.strftime("%H:%M:%S", time.gmtime(elapsed))

# %%
# %matplotlib inline
# plt.imshow(np.reshape(pred, [63, 108]))
with tf.Session as sess:
    pred = sess.run(ol, feed_dict={data_ph:[np.array(blur_img(img_set[1], blur_level=3+random.random())).ravel()]})
    plt.imshow(np.reshape(pred, [42, 42]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-fca394ad52e5> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 # plt.imshow(np.reshape(pred, [63, 108]))
# ----> 3 with tf.Session as sess:
#       4     pred = sess.run(ol, feed_dict={data_ph:[np.array(blur_img(img_set[1], blur_level=3+random.random())).ravel()]})
#       5     plt.imshow(np.reshape(pred, [42, 42]))
#
# AttributeError: __exit__
